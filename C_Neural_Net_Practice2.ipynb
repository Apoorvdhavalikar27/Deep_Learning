# %% [markdown]
# ## Neural Net Training on Digit Dataset

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('DataSets/sign_mnist_test.csv')
df_train = pd.read_csv('DataSets/sign_mnist_train.csv')

# %%
df_train
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27450     13     189     189     190     190     192     193     193     193
# 27451     23     151     154     157     158     160     161     163     164
# 27452     18     174     174     174     174     174     175     175     174
# 27453     17     177     181     184     185     187     189     190     191
# 27454     23     179     180     180     180     182     181     182     183
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27450     193  ...       132       165        99        77        52
# 27451     166  ...       198       198       198       198       198
# 27452     173  ...       121       196       209       208       206
# 27453     191  ...       119        56        27        58       102
# 27454     182  ...       108       132       170       194       214
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27450       200       234       200       222       225
# 27451       196       195       195       195       194
# 27452       204       203       202       200       200
# 27453        79        47        64        87        93
# 27454       203       197       205       209       215
#
# [27455 rows x 785 columns]

# %%
y_train = df_train.label
y_test = df_test.label

# %%
X_train = df_train.drop(columns = ['label']).values
X_test = df_test.drop(columns = ['label']).values
X_train = X_train/255
X_test = X_test/255

# %%
X_train[0].shape
# Out:
# (784,)

# %%
model = keras.Sequential([

     keras.layers.Dense(25,input_shape = (784,) ,activation = 'sigmoid')
])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
    
)

# %%
model.fit(X_train,y_train,epochs = 20)
# Out:
# Epoch 1/20
# 858/858 [==============================] - 1s 795us/step - loss: 2.2007 - accuracy: 0.4042
# Epoch 2/20
# 858/858 [==============================] - 1s 756us/step - loss: 1.4427 - accuracy: 0.6305
# Epoch 3/20
# 858/858 [==============================] - 1s 717us/step - loss: 1.1675 - accuracy: 0.7028
# Epoch 4/20
# 858/858 [==============================] - 1s 720us/step - loss: 1.0034 - accuracy: 0.7451
# Epoch 5/20
# 858/858 [==============================] - 1s 716us/step - loss: 0.8804 - accuracy: 0.7831
# Epoch 6/20
# 858/858 [==============================] - 1s 755us/step - loss: 0.7856 - accuracy: 0.8100
# Epoch 7/20
# 858/858 [==============================] - 1s 794us/step - loss: 0.7158 - accuracy: 0.8303
# Epoch 8/20
# 858/858 [==============================] - 1s 722us/step - loss: 0.6506 - accuracy: 0.8504
# Epoch 9/20
# 858/858 [==============================] - 1s 715us/step - loss: 0.6036 - accuracy: 0.8624
# Epoch 10/20
# 858/858 [==============================] - 1s 709us/step - loss: 0.5559 - accuracy: 0.8760
# Epoch 11/20
# 858/858 [==============================] - 1s 709us/step - loss: 0.5214 - accuracy: 0.8860
# Epoch 12/20
# 858/858 [==============================] - 1s 721us/step - loss: 0.4822 - accuracy: 0.8983
# Epoch 13/20
# 858/858 [==============================] - 1s 741us/step - loss: 0.4502 - accuracy: 0.9068
# Epoch 14/20
# 858/858 [==============================] - 1s 833us/step - loss: 0.4227 - accuracy: 0.9131
# Epoch 15/20
# 858/858 [==============================] - 1s 849us/step - loss: 0.3942 - accuracy: 0.9212
# Epoch 16/20
# 858/858 [==============================] - 1s 747us/step - loss: 0.3721 - accuracy: 0.9277
# Epoch 17/20
# 858/858 [==============================] - 1s 800us/step - loss: 0.3493 - accuracy: 0.9354
# Epoch 18/20
# 858/858 [==============================] - 1s 768us/step - loss: 0.3294 - accuracy: 0.9389
# Epoch 19/20
# 858/858 [==============================] - 1s 715us/step - loss: 0.3122 - accuracy: 0.9447
# Epoch 20/20
# 858/858 [==============================] - 1s 726us/step - loss: 0.2932 - accuracy: 0.9498

# %%
model.evaluate(X_test,y_test)
# Out:
# 225/225 [==============================] - 0s 752us/step - loss: 1.0168 - accuracy: 0.6979
# [1.0167685747146606, 0.6978527903556824]
